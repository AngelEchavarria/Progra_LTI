# %% [markdown]
# #**PIA PROGRMACIÓN AVANZADA**
# #**EQUIPO 4 GRUPO:22**
#
# En la Ciudad de Monterrey se celebrará un ciclo de conferencias de Tecnología.
# Las conferencias se realizarán en la Facultad de Contaduría Pública y Administración, de la UANL, los días 4, 5 y 6 de Noviembre de 2023.
# Las conferencias se realizarán en los siguientes auditorios:
# 1.	A: Gumersindo Cantú Hinojosa, con capacidad de 1000 asistentes.
# 2.	B: Víctor Gómez, con capacidad de 200 asistentes.
# 3.	C: Casas Alatriste, con capacidad de 150 asistentes.
#
# El calendario de las conferencias es el siguiente:
# 1.	4 de noviembre, a las 15:00 horas. Inteligencia Artificial en los Negocios. Dr. Alvaro Francisco Salazar, en el auditorio A.
# 2.	5 de noviembre, a las 9:00 horas. Uso de la nube para gestión de procesos. Dr. Manuel Leos, en el auditorio B.
# 3.	5 de noviembre, a las 14:00 horas. Industria 4.0 retos y oportunidades.
# Dra. Monica Hernández, en el auditorio C.
# 4.	5 de noviembre, a las 19:00 horas. Machine Learning for a better world. Dr. Janick Jameson, en el auditorio C.
# 5.	6 de noviembre, a las 15:00 horas. Retos de la Banca Electrónica en México. Ing. Clara Benavides, en el auditorio A.
#
# Se desea que desarrolles una aplicación para almacenar la información de los alumnos asistentes a los eventos, bajo la premisa que no se puede exceder la capacidad de los recintos.
#
# La información que se desea recopilar de los alumnos asistentes es matrícula, nombre, primer apellido, segundo apellido, fecha de nacimiento, carrera (LTI, LA, CP, LNI, LGRS).
#
# Se le dará constancia de participación a los alumnos que asistan a 3 o más eventos del ciclo de conferencia.

# %% [markdown]
# #**CRUD Menú de Asistentes**

# %% [markdown]
# ### **MENÚ DE LA APLICACIÓN**
#
# Lo primero que debe aparecer es el menú de la aplicación.
#
# ```
# **** MENÚ PRINCIPAL
#
# [A] Registrar un asistente.
# [B] Registrar asistente a un evento.
# [C] Registrar asistencia al evento.
# [D] Ver eventos del alumno.
# [E] Listado de asistencia a evento.
# [X] Salir
#
# Qué deseas hacer?:
#
# ```

# %%
import re
class Conferencia:
    def __init__(self):
        self.asistentes = {}

    def agregar_asistente(self, matricula, nombre, primer_apellido, segundo_apellido, fecha_nacimiento, carrera):
        self.asistentes[matricula] = {
            'nombre': nombre,
            'primer_apellido': primer_apellido,
            'segundo_apellido': segundo_apellido,
            'fecha_nacimiento': fecha_nacimiento,
            'carrera': carrera
        }
        print(f"Asistente {nombre} {primer_apellido} agregado correctamente.")

    def mostrar_asistentes(self):
        print("\nLista de Asistentes:")
        for matricula, asistente in self.asistentes.items():
            print(f"Matrícula: {matricula}, Nombre: {asistente['nombre']} {asistente['primer_apellido']} "
                  f"{asistente['segundo_apellido']} - Fecha de Nacimiento: {asistente['fecha_nacimiento']}, "
                  f"Carrera: {asistente['carrera']}")

    def actualizar_asistente(self, matricula):
        if matricula in self.asistentes:
            print("\nSeleccione qué dato desea actualizar:")
            print("1. Nombre")
            print("2. Primer Apellido")
            print("3. Segundo Apellido")
            print("4. Fecha de Nacimiento")
            print("5. Carrera")
            print("6. Actualizar todos los datos")

            opcion = input("Seleccione una opción (1-6): ")

            if opcion == '1':
                nombre = input("Ingrese el nuevo nombre del asistente: ")
                self.asistentes[matricula]['nombre'] = nombre
            elif opcion == '2':
                primer_apellido = input("Ingrese el nuevo primer apellido del asistente: ")
                self.asistentes[matricula]['primer_apellido'] = primer_apellido
            elif opcion == '3':
                segundo_apellido = input("Ingrese el nuevo segundo apellido del asistente: ")
                self.asistentes[matricula]['segundo_apellido'] = segundo_apellido
            elif opcion == '4':
                fecha_nacimiento = input("Ingrese la nueva fecha de nacimiento del asistente (YYYY-MM-DD): ")
                self.asistentes[matricula]['fecha_nacimiento'] = fecha_nacimiento
            elif opcion == '5':
                carrera = input("Ingrese la nueva carrera del asistente(LA, LNI,CP,LTI,LGRS): ")
                self.asistentes[matricula]['carrera'] = carrera
            elif opcion == '6':
                nombre = input("Ingrese el nuevo nombre del asistente: ")
                primer_apellido = input("Ingrese el nuevo primer apellido del asistente: ")
                segundo_apellido = input("Ingrese el nuevo segundo apellido del asistente: ")
                fecha_nacimiento = input("Ingrese la nueva fecha de nacimiento del asistente (YYYY-MM-DD): ")
                carrera = input("Ingrese la nueva carrera del asistente(LA, LNI,CP,LTI,LGRS): ")

                self.asistentes[matricula] = {
                    'nombre': nombre,
                    'primer_apellido': primer_apellido,
                    'segundo_apellido': segundo_apellido,
                    'fecha_nacimiento': fecha_nacimiento,
                    'carrera': carrera
                }

            print("Asistente actualizado correctamente.")
        else:
            print("Matrícula de asistente no encontrada.")

    def eliminar_asistente(self, matricula):
        if matricula in self.asistentes:
            asistente = self.asistentes.pop(matricula)
            print(f"Asistente {asistente['nombre']} {asistente['primer_apellido']} eliminado correctamente.")
        else:
            print("Matrícula de asistente no encontrada.")


def menu():
    print("\n--- Menú de Conferencia ---")
    print("1. Agregar Asistente")
    print("2. Mostrar Asistentes")
    print("3. Actualizar Asistente")
    print("4. Eliminar Asistente")
    print("5. Salir")
    opcion = input("Seleccione una opción (1-5): ")
    return opcion


def main():
    conferencia = Conferencia()

    while True:
        opcion = menu()

        if opcion == '1':
            matricula = input("Ingrese la matrícula del asistente: ")
            nombre = input("Ingrese el nombre del asistente: ")
            primer_apellido = input("Ingrese el primer apellido del asistente: ")
            segundo_apellido = input("Ingrese el segundo apellido del asistente: ")
            fecha_nacimiento = input("Ingrese la fecha de nacimiento del asistente (YYYY-MM-DD): ")
            carrera = input("Ingrese la carrera del asistente(LA, LNI,CP,LTI,LGRS): ")

            conferencia.agregar_asistente(matricula, nombre, primer_apellido, segundo_apellido, fecha_nacimiento, carrera)

        elif opcion == '2':
            conferencia.mostrar_asistentes()

        elif opcion == '3':
            matricula = input("Ingrese la matrícula del asistente a actualizar: ")
            conferencia.actualizar_asistente(matricula)

        elif opcion == '4':
            matricula = input("Ingrese la matrícula del asistente a eliminar: ")
            conferencia.eliminar_asistente(matricula)

        elif opcion == '5':
            print("Saliendo del programa. ¡Hasta luego!")
            break

        else:
            print("Opción no válida. Por favor, seleccione una opción válida.")


if __name__ == "__main__":
    main()
# Out:
# --- Menú de Conferencia ---
# 1. Agregar Asistente
# 2. Mostrar Asistentes
# 3. Actualizar Asistente
# 4. Eliminar Asistente
# 5. Salir
# Seleccione una opción (1-5): 4
# Ingrese la matrícula del asistente a eliminar: 212121
# Matrícula de asistente no encontrada.
#
# --- Menú de Conferencia ---
# 1. Agregar Asistente
# 2. Mostrar Asistentes
# 3. Actualizar Asistente
# 4. Eliminar Asistente
# 5. Salir
# Seleccione una opción (1-5): 2
#
# Lista de Asistentes:
#
# --- Menú de Conferencia ---
# 1. Agregar Asistente
# 2. Mostrar Asistentes
# 3. Actualizar Asistente
# 4. Eliminar Asistente
# 5. Salir
# Seleccione una opción (1-5): 555
# Opción no válida. Por favor, seleccione una opción válida.
#
# --- Menú de Conferencia ---
# 1. Agregar Asistente
# 2. Mostrar Asistentes
# 3. Actualizar Asistente
# 4. Eliminar Asistente
# 5. Salir
# Seleccione una opción (1-5): 2
#
# Lista de Asistentes:
#
# --- Menú de Conferencia ---
# 1. Agregar Asistente
# 2. Mostrar Asistentes
# ...
